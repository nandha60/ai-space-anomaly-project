# %% [markdown]
# # NASA CMAPSS Exploratory Data Analysis
#
# This notebook provides a basic analysis of the FD001 dataset.

# %%
import os
import sys
import yaml
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sys.path.append('../src')
from data import CMAPSSDataHandler

with open('../config.yaml', 'r') as file:
    config = yaml.safe_load(file)

# Update paths for notebook execution
config['data']['train_path'] = '../' + config['data']['train_path']
config['data']['test_path'] = '../' + config['data']['test_path']
config['data']['rul_path'] = '../' + config['data']['rul_path']

handler = CMAPSSDataHandler(config)
print('Data Handler Initialized!')
